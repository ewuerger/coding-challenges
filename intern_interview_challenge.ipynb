# %% [markdown]
# # Python, OOP & AI Prompt Engineering Interview Challenge
#
# ## Overview
#
# This interview challenge tests your foundational knowledge in three key areas:
#
# 1. **Python Fundamentals** - Basic data structures and string manipulation
# 2. **Object-Oriented Programming** - Classes definitions
# 3. **AI Prompt Engineering** - Structured prompting techniques for AI systems
#
# The challenge are designed for interns and focuse on demonstrating understanding of core concepts rather than production-ready implementations.
#
# **Instructions:**
#
# - Share your screen while working through the problems
# - Read each problem carefully
# - Implement your solutions in the provided code cells or explain your approach
# - You may use Python documentation for reference
# - **LLMs** are part of our everyday workflow. If needed, you can use LLMs or local coding agents and share openly what helper tools you use. \
#   Be transparent about it and share which helper tools you use. You may download the Jupyter notebook and run it locally.
# - **Time estimate:** ~30 minutes

# %% [markdown]
# ---
#
# # Part 1: Python Fundamentals
#
# ## Problem 1.1: Word Count Challenge
#
# Write a function that takes a string and returns an adequate datastructure. How does the output look like?

# %%
import typing as t


def word_count(text: str) -> t.Any:
    """Count the frequency of each word in the given text.

    Parameters
    ----------
    text: Input string to analyze

    Returns
    -------
    word_count: The expected result
    """
    # Your code goes here
    pass


test_text = "I felt happy because I saw the others were happy and because I knew I should feel happy, but I wasn't really happy."
print(word_count(test_text))

# %% [markdown]
# ## Problem 2: Derive an ontology from the given problem
#
# ### Problem Definition: Pet Daycare System
#
# You are building a simple pet daycare booking system.
#
# **Requirements:**
#
# 1. The daycare accepts **dogs** and **cats**:
#    - Dogs have: name, breed, age, vaccination status
#    - Cats have: name, breed, age, indoor/outdoor preference
#
# 2. All pets need to:
#    - Check in and check out
#    - Have an owner contact (name and phone number)
#    - Track if they are currently at the daycare
#
# 3. Pricing:
#    - Dogs: €25 per day (€35 if not vaccinated)
#    - Cats: €20 per day
#
# ---
#
# ### Your Task:
#
# **Design the class structure for this system.**
#
# Identify:
#
# 1. What classes do you need?
# 2. What attributes does each class have?
# 3. What methods does each class need?
# 4. Should you use inheritance, composition or both? Why?
#
# Implement your design below.

# %%
# Design and implement your class structure here
#
# Think about:
# - What's common between dogs and cats? (base class)
# - What's different? (derived classes)
# - How do you handle owner contact?
# - How do you calculate different prices?

# Your implementation:

# %% [markdown]
# ---
#
# # Part 3: AI Prompt Engineering
#
# ## Structured Prompts
#
# 1. **Zero-shot**
# 2. **One-shot**
# 3. **Few-shot**
# 4. **Chain of Thought**
# 5. **Dynamic**
# 6. ...
# 7. **Tool call**

# %% [markdown]
# ## Problem 3.1: Zero-shot Prompting
#
# **Task:** Write a prompt for a coding assistent that solves simple coding problems.

# %% [markdown]
# ## Problem 3.2: One-shot Prompting
#
# **Task:** Convert the Zero-shot prompt to a one-shot prompt.

# %% [markdown]
# ## Problem 3.3: Chain of Thought
#
# **Task:** Convert the Zero-shot prompt to a CoT prompt.

# %% [markdown]
# ## Problem 3.4: Tool Calling
#
# **Task:** Define a tool for the agent to call `web_search()`. How would you change the CoT prompt accordingly?

# %%
# definition of web_search() tool
def web_search(query: str) -> str:
    """Simulates a web search and returns a summary of results.

    Parameters
    ----------
    query: The search query string.

    Returns
    -------
    summary: A summary of the search results.
    """
    ...
